# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE

cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)
# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 735

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # city_weather_description = city_weather["weather"]["description"]
        # I kept getting a type error on the weather and ran out of time to figure it out.
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | skjervoy
# Processing Record 4 of Set 1 | auch
# Processing Record 5 of Set 1 | killybegs
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | slave lake
# Processing Record 8 of Set 1 | bejar
# Processing Record 9 of Set 1 | bowen
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | tuatapere
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | vikhorevka
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | mandalgovi
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | camacha
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | saint-augustin
# Processing Record 23 of Set 1 | llangefni
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | boda
# Processing Record 26 of Set 1 | hammerfest
# Processing Record 27 of Set 1 | shenzhen
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | inta
# Processing Record 30 of Set 1 | severodvinsk
# Processing Record 31 of Set 1 | kitui
# Processing Record 32 of Set 1 | waipawa
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | ocampo
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | flinders
# Processing Record 42 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | great yarmouth
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | marsa matruh
# Processing Record 49 of Set 1 | pakxan
# Processing Record 50 of Set 1 | zherdevka
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | prado
# Processing Record 5 of Set 2 | caetite
# Processing Record 6 of Set 2 | warmbad
# Processing Record 7 of Set 2 | san carlos de bariloche
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | lashio
# Processing Record 12 of Set 2 | sembe
# Processing Record 13 of Set 2 | pandan niog
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | pacific grove
# Processing Record 22 of Set 2 | peniche
# Processing Record 23 of Set 2 | manggar
# Processing Record 24 of Set 2 | shaunavon
# Processing Record 25 of Set 2 | vredendal
# Processing Record 26 of Set 2 | charters towers
# Processing Record 27 of Set 2 | bontang
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | riyadh
# Processing Record 30 of Set 2 | sharlyk
# Processing Record 31 of Set 2 | montepuez
# Processing Record 32 of Set 2 | busselton
# Processing Record 33 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | rocha
# Processing Record 36 of Set 2 | korla
# Processing Record 37 of Set 2 | port angeles
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | kenai
# Processing Record 40 of Set 2 | zyryanka
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | quelimane
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | roald
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | malu mare
# Processing Record 48 of Set 2 | celestun
# Processing Record 49 of Set 2 | lahaina
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | concarneau
# Processing Record 2 of Set 3 | olinda
# Processing Record 3 of Set 3 | walvis bay
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | coihaique
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | santa rosa
# Processing Record 17 of Set 3 | vila franca do campo
# Processing Record 18 of Set 3 | sabang
# Processing Record 19 of Set 3 | namtsy
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | ha tinh
# Processing Record 24 of Set 3 | ouadda
# Processing Record 25 of Set 3 | zunyi
# Processing Record 26 of Set 3 | almeria
# Processing Record 27 of Set 3 | puerto baquerizo moreno
# Processing Record 28 of Set 3 | harrisonburg
# Processing Record 29 of Set 3 | bulgan
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | sandpoint
# Processing Record 33 of Set 3 | makakilo city
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | corn island
# Processing Record 36 of Set 3 | saint-denis
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | kyra
# Processing Record 39 of Set 3 | alihe
# Processing Record 40 of Set 3 | lima
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | agua buena
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | wampusirpi
# City not found. Skipping...
# Processing Record 46 of Set 3 | cascais
# Processing Record 47 of Set 3 | sistranda
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | bantou
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | lac-megantic
# Processing Record 5 of Set 4 | paredon
# Processing Record 6 of Set 4 | liverpool
# Processing Record 7 of Set 4 | kindu
# Processing Record 8 of Set 4 | sioux lookout
# Processing Record 9 of Set 4 | kiruna
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | qena
# Processing Record 13 of Set 4 | moranbah
# Processing Record 14 of Set 4 | kovur
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | swakopmund
# Processing Record 17 of Set 4 | ahipara
# Processing Record 18 of Set 4 | mount isa
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | pahalgam
# Processing Record 21 of Set 4 | provideniya
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | rigaud
# Processing Record 24 of Set 4 | vavuniya
# Processing Record 25 of Set 4 | egvekinot
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | yulara
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | beira
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | derzhavinsk
# Processing Record 34 of Set 4 | maniitsoq
# Processing Record 35 of Set 4 | yarada
# Processing Record 36 of Set 4 | college
# Processing Record 37 of Set 4 | ramsar
# Processing Record 38 of Set 4 | ziro
# Processing Record 39 of Set 4 | tessalit
# Processing Record 40 of Set 4 | salinopolis
# Processing Record 41 of Set 4 | kibondo
# Processing Record 42 of Set 4 | samarai
# Processing Record 43 of Set 4 | kirovsk
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | ostrovnoy
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | alofi
# Processing Record 48 of Set 4 | masterton
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | boa vista
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | parelhas
# Processing Record 4 of Set 5 | bonavista
# Processing Record 5 of Set 5 | chokwe
# Processing Record 6 of Set 5 | artyom
# Processing Record 7 of Set 5 | umba
# Processing Record 8 of Set 5 | hamilton
# Processing Record 9 of Set 5 | hailar
# Processing Record 10 of Set 5 | wanning
# Processing Record 11 of Set 5 | namibe
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | kazerun
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | huadian
# Processing Record 18 of Set 5 | jalu
# Processing Record 19 of Set 5 | impfondo
# Processing Record 20 of Set 5 | port maria
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | atikokan
# Processing Record 24 of Set 5 | hovd
# Processing Record 25 of Set 5 | humlebaek
# Processing Record 26 of Set 5 | geraldton
# Processing Record 27 of Set 5 | palmer
# Processing Record 28 of Set 5 | guerrero negro
# Processing Record 29 of Set 5 | kutum
# Processing Record 30 of Set 5 | khandyga
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | tasiilaq
# Processing Record 33 of Set 5 | norrtalje
# Processing Record 34 of Set 5 | tawang
# Processing Record 35 of Set 5 | bani
# Processing Record 36 of Set 5 | oudtshoorn
# Processing Record 37 of Set 5 | maldonado
# Processing Record 38 of Set 5 | belyy yar
# Processing Record 39 of Set 5 | wahpeton
# Processing Record 40 of Set 5 | tadotsu
# Processing Record 41 of Set 5 | tartus
# Processing Record 42 of Set 5 | vila praia de ancora
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | poum
# Processing Record 45 of Set 5 | henties bay
# Processing Record 46 of Set 5 | jacareacanga
# Processing Record 47 of Set 5 | cairns
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | jijiga
# Processing Record 50 of Set 5 | umm lajj
# Processing Record 1 of Set 6 | avera
# Processing Record 2 of Set 6 | sohag
# Processing Record 3 of Set 6 | yaqui
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | castro
# Processing Record 6 of Set 6 | kota kinabalu
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | darlawn
# Processing Record 9 of Set 6 | pangai
# Processing Record 10 of Set 6 | zhigansk
# Processing Record 11 of Set 6 | taltal
# Processing Record 12 of Set 6 | touros
# Processing Record 13 of Set 6 | sorong
# Processing Record 14 of Set 6 | chokurdakh
# Processing Record 15 of Set 6 | san quintin
# Processing Record 16 of Set 6 | cherskiy
# Processing Record 17 of Set 6 | manokwari
# Processing Record 18 of Set 6 | magdagachi
# Processing Record 19 of Set 6 | san jeronimo
# Processing Record 20 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 6 | mahebourg
# Processing Record 22 of Set 6 | chaman
# Processing Record 23 of Set 6 | santa cruz
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | hofn
# Processing Record 26 of Set 6 | deputatskiy
# Processing Record 27 of Set 6 | zakharo
# City not found. Skipping...
# Processing Record 28 of Set 6 | merzig
# Processing Record 29 of Set 6 | asosa
# Processing Record 30 of Set 6 | astoria
# Processing Record 31 of Set 6 | zabol
# Processing Record 32 of Set 6 | iracoubo
# Processing Record 33 of Set 6 | anzio
# Processing Record 34 of Set 6 | ludwigslust
# Processing Record 35 of Set 6 | quatre cocos
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | englehart
# Processing Record 38 of Set 6 | talcahuano
# Processing Record 39 of Set 6 | saint-francois
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | shikhany
# Processing Record 43 of Set 6 | kawalu
# Processing Record 44 of Set 6 | jos
# Processing Record 45 of Set 6 | ryazhsk
# Processing Record 46 of Set 6 | yerbogachen
# Processing Record 47 of Set 6 | uusikaupunki
# Processing Record 48 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 6 | sakakah
# Processing Record 50 of Set 6 | faxinal
# Processing Record 1 of Set 7 | goundam
# Processing Record 2 of Set 7 | vallenar
# Processing Record 3 of Set 7 | brae
# Processing Record 4 of Set 7 | ketchikan
# Processing Record 5 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 7 | broome
# Processing Record 7 of Set 7 | buala
# Processing Record 8 of Set 7 | san lorenzo
# Processing Record 9 of Set 7 | inirida
# Processing Record 10 of Set 7 | matara
# Processing Record 11 of Set 7 | laguna
# Processing Record 12 of Set 7 | changzhou
# Processing Record 13 of Set 7 | qasigiannguit
# Processing Record 14 of Set 7 | kayes
# Processing Record 15 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 7 | saucillo
# Processing Record 17 of Set 7 | sonipat
# Processing Record 18 of Set 7 | zalesovo
# Processing Record 19 of Set 7 | sinnamary
# Processing Record 20 of Set 7 | alnashi
# Processing Record 21 of Set 7 | tambacounda
# Processing Record 22 of Set 7 | don sak
# Processing Record 23 of Set 7 | drayton valley
# Processing Record 24 of Set 7 | mackay
# Processing Record 25 of Set 7 | boke
# Processing Record 26 of Set 7 | omsukchan
# Processing Record 27 of Set 7 | mokrous
# Processing Record 28 of Set 7 | corinto
# Processing Record 29 of Set 7 | tamiahua
# Processing Record 30 of Set 7 | cangzhou
# Processing Record 31 of Set 7 | tiksi
# Processing Record 32 of Set 7 | porto velho
# Processing Record 33 of Set 7 | almeirim
# Processing Record 34 of Set 7 | matagami
# Processing Record 35 of Set 7 | takoradi
# Processing Record 36 of Set 7 | brigantine
# Processing Record 37 of Set 7 | santiago del estero
# Processing Record 38 of Set 7 | mezhdurechensk
# Processing Record 39 of Set 7 | san vicente
# Processing Record 40 of Set 7 | belo oriente
# Processing Record 41 of Set 7 | vila
# Processing Record 42 of Set 7 | nortelandia
# Processing Record 43 of Set 7 | vuktyl
# Processing Record 44 of Set 7 | praya
# Processing Record 45 of Set 7 | hasaki
# Processing Record 46 of Set 7 | dhangadhi
# Processing Record 47 of Set 7 | altay
# Processing Record 48 of Set 7 | nantucket
# Processing Record 49 of Set 7 | saint anthony
# Processing Record 50 of Set 7 | salalah
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | mouzakion
# City not found. Skipping...
# Processing Record 3 of Set 8 | san rafael del sur
# Processing Record 4 of Set 8 | atar
# Processing Record 5 of Set 8 | tiznit
# Processing Record 6 of Set 8 | huarmey
# Processing Record 7 of Set 8 | san ramon
# Processing Record 8 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 8 | kuusamo
# Processing Record 10 of Set 8 | morant bay
# Processing Record 11 of Set 8 | bonthe
# Processing Record 12 of Set 8 | botwood
# Processing Record 13 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 8 | evensk
# Processing Record 15 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 8 | conceicao da barra
# Processing Record 17 of Set 8 | katsuura
# Processing Record 18 of Set 8 | kruisfontein
# Processing Record 19 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 20 of Set 8 | faanui
# Processing Record 21 of Set 8 | banda aceh
# Processing Record 22 of Set 8 | susanville
# Processing Record 23 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 8 | antalaha
# Processing Record 25 of Set 8 | parrsboro
# Processing Record 26 of Set 8 | sangar
# Processing Record 27 of Set 8 | vysokogornyy
# Processing Record 28 of Set 8 | chicama
# Processing Record 29 of Set 8 | burnie
# Processing Record 30 of Set 8 | grand gaube
# Processing Record 31 of Set 8 | port-gentil
# Processing Record 32 of Set 8 | mao
# Processing Record 33 of Set 8 | kailua
# Processing Record 34 of Set 8 | aquiraz
# Processing Record 35 of Set 8 | debre tabor
# Processing Record 36 of Set 8 | baruun-urt
# Processing Record 37 of Set 8 | tyrma
# Processing Record 38 of Set 8 | sao joao da barra
# Processing Record 39 of Set 8 | broken hill
# Processing Record 40 of Set 8 | biak
# Processing Record 41 of Set 8 | dali
# Processing Record 42 of Set 8 | ixtapa
# Processing Record 43 of Set 8 | hay river
# Processing Record 44 of Set 8 | pitimbu
# Processing Record 45 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 8 | kabompo
# Processing Record 47 of Set 8 | comodoro rivadavia
# Processing Record 48 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 8 | kidal
# Processing Record 50 of Set 8 | maceio
# Processing Record 1 of Set 9 | balikpapan
# Processing Record 2 of Set 9 | suntar
# Processing Record 3 of Set 9 | tuktoyaktuk
# Processing Record 4 of Set 9 | chernyshevskiy
# Processing Record 5 of Set 9 | burica
# City not found. Skipping...
# Processing Record 6 of Set 9 | los llanos de aridane
# Processing Record 7 of Set 9 | gimli
# Processing Record 8 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 9 | valparaiso
# Processing Record 10 of Set 9 | mitsamiouli
# Processing Record 11 of Set 9 | puerto ayacucho
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | dera bugti
# Processing Record 14 of Set 9 | nemuro
# Processing Record 15 of Set 9 | nuuk
# Processing Record 16 of Set 9 | clyde river
# Processing Record 17 of Set 9 | bethel
# Processing Record 18 of Set 9 | kununurra
# Processing Record 19 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 9 | dunedin
# Processing Record 21 of Set 9 | vila velha
# Processing Record 22 of Set 9 | yunyang
# Processing Record 23 of Set 9 | abnub
# Processing Record 24 of Set 9 | rosario oeste
# Processing Record 25 of Set 9 | beyneu
# Processing Record 26 of Set 9 | manaus
# Processing Record 27 of Set 9 | ambilobe
# Processing Record 28 of Set 9 | ulaangom
# Processing Record 29 of Set 9 | mayumba
# Processing Record 30 of Set 9 | rudnogorsk
# Processing Record 31 of Set 9 | simnas
# Processing Record 32 of Set 9 | arlit
# Processing Record 33 of Set 9 | massaguet
# Processing Record 34 of Set 9 | fredericton
# Processing Record 35 of Set 9 | santa lucia
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | oktyabrskiy
# Processing Record 38 of Set 9 | turbat
# Processing Record 39 of Set 9 | wewak
# Processing Record 40 of Set 9 | hambantota
# Processing Record 41 of Set 9 | tallahassee
# Processing Record 42 of Set 9 | te anau
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | mexico
# Processing Record 45 of Set 9 | benguela
# Processing Record 46 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 9 | ambulu
# Processing Record 48 of Set 9 | dmitriyevka
# Processing Record 49 of Set 9 | turkmenabat
# Processing Record 50 of Set 9 | luang prabang
# Processing Record 1 of Set 10 | nisia floresta
# Processing Record 2 of Set 10 | baiyin
# Processing Record 3 of Set 10 | port hedland
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | havre-saint-pierre
# Processing Record 6 of Set 10 | san cristobal
# Processing Record 7 of Set 10 | aswan
# Processing Record 8 of Set 10 | guanajuato
# Processing Record 9 of Set 10 | makung
# City not found. Skipping...
# Processing Record 10 of Set 10 | ugoofaaru
# Processing Record 11 of Set 10 | chumikan
# Processing Record 12 of Set 10 | kinablangan
# Processing Record 13 of Set 10 | mahajanga
# Processing Record 14 of Set 10 | huangmei
# Processing Record 15 of Set 10 | tongchuan
# Processing Record 16 of Set 10 | shieli
# Processing Record 17 of Set 10 | port-cartier
# Processing Record 18 of Set 10 | margate
# Processing Record 19 of Set 10 | tera
# Processing Record 20 of Set 10 | stornoway
# Processing Record 21 of Set 10 | bengkulu
# Processing Record 22 of Set 10 | denpasar
# Processing Record 23 of Set 10 | chitrakonda
# Processing Record 24 of Set 10 | buchanan
# Processing Record 25 of Set 10 | novoagansk
# Processing Record 26 of Set 10 | broumov
# Processing Record 27 of Set 10 | bay roberts
# Processing Record 28 of Set 10 | santa filomena
# Processing Record 29 of Set 10 | hauterive
# Processing Record 30 of Set 10 | batemans bay
# Processing Record 31 of Set 10 | asau
# Processing Record 32 of Set 10 | goderich
# Processing Record 33 of Set 10 | el molino
# Processing Record 34 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 10 | lagunas
# Processing Record 36 of Set 10 | kyaikkami
# Processing Record 37 of Set 10 | hwange
# Processing Record 38 of Set 10 | necochea
# Processing Record 39 of Set 10 | andahuaylas
# Processing Record 40 of Set 10 | vangaindrano
# Processing Record 41 of Set 10 | maragogi
# Processing Record 42 of Set 10 | loiza
# Processing Record 43 of Set 10 | strezhevoy
# Processing Record 44 of Set 10 | bugiri
# Processing Record 45 of Set 10 | vestmanna
# Processing Record 46 of Set 10 | paragominas
# Processing Record 47 of Set 10 | dandong
# Processing Record 48 of Set 10 | arkhangelos
# City not found. Skipping...
# Processing Record 49 of Set 10 | porto novo
# Processing Record 50 of Set 10 | piet retief
# Processing Record 1 of Set 11 | rio grande
# Processing Record 2 of Set 11 | upernavik
# Processing Record 3 of Set 11 | barcelona
# Processing Record 4 of Set 11 | noumea
# Processing Record 5 of Set 11 | coos bay
# Processing Record 6 of Set 11 | coihueco
# Processing Record 7 of Set 11 | talnakh
# Processing Record 8 of Set 11 | la asuncion
# Processing Record 9 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 10 of Set 11 | mizdah
# Processing Record 11 of Set 11 | le havre
# Processing Record 12 of Set 11 | kirensk
# Processing Record 13 of Set 11 | shadegan
# Processing Record 14 of Set 11 | lagos de moreno
# Processing Record 15 of Set 11 | fort saint james
# Processing Record 16 of Set 11 | neijiang
# Processing Record 17 of Set 11 | ilulissat
# Processing Record 18 of Set 11 | bubaque
# Processing Record 19 of Set 11 | imeni poliny osipenko
# Processing Record 20 of Set 11 | saint-joseph
# Processing Record 21 of Set 11 | mfou
# Processing Record 22 of Set 11 | annigeri
# Processing Record 23 of Set 11 | krasnoarmeysk
# Processing Record 24 of Set 11 | sitionuevo
# Processing Record 25 of Set 11 | sao francisco de paula
# Processing Record 26 of Set 11 | kalianget
# Processing Record 27 of Set 11 | mweka
# Processing Record 28 of Set 11 | vao
# Processing Record 29 of Set 11 | fayaoue
# Processing Record 30 of Set 11 | deer lake
# Processing Record 31 of Set 11 | poya
# Processing Record 32 of Set 11 | pointe michel
# Processing Record 33 of Set 11 | gigmoto
# Processing Record 34 of Set 11 | carupano
# Processing Record 35 of Set 11 | kaele
# Processing Record 36 of Set 11 | santa fe
# Processing Record 37 of Set 11 | kilindoni
# Processing Record 38 of Set 11 | yar-sale
# Processing Record 39 of Set 11 | ibra
# Processing Record 40 of Set 11 | haines junction
# Processing Record 41 of Set 11 | yenagoa
# Processing Record 42 of Set 11 | novobiryusinskiy
# Processing Record 43 of Set 11 | ximei
# Processing Record 44 of Set 11 | zitsa
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | tchollire
# Processing Record 47 of Set 11 | northam
# Processing Record 48 of Set 11 | kendari
# Processing Record 49 of Set 11 | san jose
# Processing Record 50 of Set 11 | kosa
# Processing Record 1 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 2 of Set 12 | marawi
# Processing Record 3 of Set 12 | arequipa
# Processing Record 4 of Set 12 | rumoi
# Processing Record 5 of Set 12 | nouadhibou
# Processing Record 6 of Set 12 | chiredzi
# Processing Record 7 of Set 12 | aktash
# Processing Record 8 of Set 12 | pyapon
# Processing Record 9 of Set 12 | manoel urbano
# Processing Record 10 of Set 12 | marzuq
# Processing Record 11 of Set 12 | zeya
# Processing Record 12 of Set 12 | bacolod
# Processing Record 13 of Set 12 | shetpe
# Processing Record 14 of Set 12 | nishihara
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | dhidhdhoo
# Processing Record 17 of Set 12 | berbera
# Processing Record 18 of Set 12 | tutoia
# Processing Record 19 of Set 12 | ales
# Processing Record 20 of Set 12 | naze
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | shimanovsk
# Processing Record 23 of Set 12 | dois corregos
# Processing Record 24 of Set 12 | nacajuca
# Processing Record 25 of Set 12 | never
# Processing Record 26 of Set 12 | misratah
# Processing Record 27 of Set 12 | sombrio
# Processing Record 28 of Set 12 | dudinka
# Processing Record 29 of Set 12 | vilhena
# Processing Record 30 of Set 12 | baoning
# Processing Record 31 of Set 12 | martyush
# Processing Record 32 of Set 12 | prieska
# Processing Record 33 of Set 12 | macrohon
# Processing Record 34 of Set 12 | dingle
# Processing Record 35 of Set 12 | praia da vitoria
# Processing Record 36 of Set 12 | sao filipe
# Processing Record 37 of Set 12 | kungurtug
# Processing Record 38 of Set 12 | bankfoot
# Processing Record 39 of Set 12 | nuoro
# Processing Record 40 of Set 12 | kayasula
# Processing Record 41 of Set 12 | yumen
# Processing Record 42 of Set 12 | narsaq
# Processing Record 43 of Set 12 | seoul
# Processing Record 44 of Set 12 | ligayan
# Processing Record 45 of Set 12 | caravelas
# Processing Record 46 of Set 12 | luanda
# Processing Record 47 of Set 12 | khonsar
# City not found. Skipping...
# Processing Record 48 of Set 12 | katherine
# Processing Record 49 of Set 12 | millinocket
# Processing Record 50 of Set 12 | jiuquan
# Processing Record 1 of Set 13 | bandarbeyla
# Processing Record 2 of Set 13 | hami
# Processing Record 3 of Set 13 | ormara
# Processing Record 4 of Set 13 | samatau
# City not found. Skipping...
# Processing Record 5 of Set 13 | nagykoros
# Processing Record 6 of Set 13 | newnan
# Processing Record 7 of Set 13 | penapolis
# Processing Record 8 of Set 13 | russell
# Processing Record 9 of Set 13 | opuwo
# Processing Record 10 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 13 | greytown
# Processing Record 12 of Set 13 | novokruchininskiy
# Processing Record 13 of Set 13 | wakkanai
# Processing Record 14 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 13 | bharatpur
# Processing Record 16 of Set 13 | aksu
# Processing Record 17 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 13 | lorengau
# Processing Record 19 of Set 13 | concepcion del oro
# Processing Record 20 of Set 13 | livingston
# Processing Record 21 of Set 13 | svetogorsk
# Processing Record 22 of Set 13 | leshukonskoye
# Processing Record 23 of Set 13 | kanniyakumari
# Processing Record 24 of Set 13 | sorland
# Processing Record 25 of Set 13 | soyo
# Processing Record 26 of Set 13 | sola
# Processing Record 27 of Set 13 | zalantun
# Processing Record 28 of Set 13 | scarborough
# Processing Record 29 of Set 13 | huilong
# Processing Record 30 of Set 13 | batagay-alyta
# Processing Record 31 of Set 13 | nefteyugansk
# Processing Record 32 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 13 | khomeyn
# Processing Record 34 of Set 13 | umea
# Processing Record 35 of Set 13 | robertsport
# Processing Record 36 of Set 13 | belaya gora
# Processing Record 37 of Set 13 | kirovskiy
# Processing Record 38 of Set 13 | nizhniy tsasuchey
# Processing Record 39 of Set 13 | goias
# Processing Record 40 of Set 13 | ostrowiec swietokrzyski
# Processing Record 41 of Set 13 | merauke
# Processing Record 42 of Set 13 | pangnirtung
# Processing Record 43 of Set 13 | boyuibe
# Processing Record 44 of Set 13 | rudbar
# Processing Record 45 of Set 13 | brighton
# Processing Record 46 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 13 | rundu
# Processing Record 48 of Set 13 | zhuhai
# Processing Record 49 of Set 13 | labuhan
# Processing Record 50 of Set 13 | magan
# Processing Record 1 of Set 14 | manitouwadge
# Processing Record 2 of Set 14 | araouane
# Processing Record 3 of Set 14 | meiganga
# Processing Record 4 of Set 14 | pangody
# Processing Record 5 of Set 14 | kodino
# Processing Record 6 of Set 14 | sayyan
# Processing Record 7 of Set 14 | lindenberg
# Processing Record 8 of Set 14 | astana
# Processing Record 9 of Set 14 | rio do sul
# Processing Record 10 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 14 | paamiut
# Processing Record 12 of Set 14 | longkou
# Processing Record 13 of Set 14 | florida
# Processing Record 14 of Set 14 | hagere selam
# Processing Record 15 of Set 14 | novobirilyussy
# Processing Record 16 of Set 14 | vestmannaeyjar
# Processing Record 17 of Set 14 | ransang
# Processing Record 18 of Set 14 | uthal
# Processing Record 19 of Set 14 | cap malheureux
# Processing Record 20 of Set 14 | zhicheng
# Processing Record 21 of Set 14 | general roca
# Processing Record 22 of Set 14 | dalbandin
# Processing Record 23 of Set 14 | aksarka
# Processing Record 24 of Set 14 | soe
# Processing Record 25 of Set 14 | itapua poty
# City not found. Skipping...
# Processing Record 26 of Set 14 | arroyo
# Processing Record 27 of Set 14 | tautira
# Processing Record 28 of Set 14 | balkanabat
# Processing Record 29 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 30 of Set 14 | darhan
# Processing Record 31 of Set 14 | matay
# Processing Record 32 of Set 14 | xuddur
# Processing Record 33 of Set 14 | souillac
# Processing Record 34 of Set 14 | salinas
# Processing Record 35 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 14 | ichinoseki
# Processing Record 37 of Set 14 | dongsheng
# Processing Record 38 of Set 14 | svetlogorsk
# Processing Record 39 of Set 14 | churapcha
# Processing Record 40 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 14 | rio gallegos
# Processing Record 42 of Set 14 | luau
# Processing Record 43 of Set 14 | kurchum
# Processing Record 44 of Set 14 | luwingu
# Processing Record 45 of Set 14 | maarianhamina
# Processing Record 46 of Set 14 | marataizes
# Processing Record 47 of Set 14 | sidhi
# Processing Record 48 of Set 14 | kirakira
# Processing Record 49 of Set 14 | lavrentiya
# Processing Record 50 of Set 14 | tomohon
# Processing Record 1 of Set 15 | eldorado
# Processing Record 2 of Set 15 | olean
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | neiafu
# Processing Record 5 of Set 15 | nyborg
# Processing Record 6 of Set 15 | dutse
# Processing Record 7 of Set 15 | aksarayskiy
# Processing Record 8 of Set 15 | richards bay
# Processing Record 9 of Set 15 | marystown
# Processing Record 10 of Set 15 | jumla
# Processing Record 11 of Set 15 | turukhansk
# Processing Record 12 of Set 15 | ottawa
# Processing Record 13 of Set 15 | mogok
# Processing Record 14 of Set 15 | drovyanaya
# Processing Record 15 of Set 15 | kasempa
# Processing Record 16 of Set 15 | awbari
# Processing Record 17 of Set 15 | saint-alexandre
# Processing Record 18 of Set 15 | boysun
# Processing Record 19 of Set 15 | half moon bay
# Processing Record 20 of Set 15 | emerald
# Processing Record 21 of Set 15 | ayia marina
# Processing Record 22 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 15 | norilsk
# Processing Record 24 of Set 15 | grindavik
# Processing Record 25 of Set 15 | jonesboro
# Processing Record 26 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 15 | bintulu
# Processing Record 29 of Set 15 | port blair
# Processing Record 30 of Set 15 | charlestown
# Processing Record 31 of Set 15 | glenwood springs
# Processing Record 32 of Set 15 | byron bay
# Processing Record 33 of Set 15 | maningrida
# Processing Record 34 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 15 | ossora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Pevek  69.7008  170.3133     28.42        95         100       30.24
# 1  Yellowknife  62.4560 -114.3525     50.56        57          40       10.36
# 2     Skjervoy  70.0311   20.9714     48.20        88         100       21.68
# 3         Auch  43.6500    0.5833     65.34        81          39        3.18
# 4    Killybegs  54.6333   -8.4500     56.91        85         100       25.41
# 5         Tura  25.5198   90.2201     71.69        97          22        3.42
# 6   Slave Lake  55.2834 -114.7690     46.38        76           0        6.91
# 7        Bejar  40.3864   -5.7634     68.58        59         100        2.28
# 8        Bowen -20.0167  148.2333     73.56        80          31       17.05
# 9     Olafsvik  64.8945  -23.7142     41.61        68          75       13.06
#
#   Country                 Date
# 0      RU  2022-10-06 18:28:53
# 1      CA  2022-10-06 18:36:13
# 2      NO  2022-10-06 18:36:14
# 3      FR  2022-10-06 18:36:14
# 4      IE  2022-10-06 18:36:15
# 5      IN  2022-10-06 18:36:15
# 6      CA  2022-10-06 18:35:51
# 7      ES  2022-10-06 18:36:16
# 8      AU  2022-10-06 18:36:16
# 9      IS  2022-10-06 18:36:16

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
cols = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[cols]
# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pevek      RU  69.7008  170.3133     28.42        95         100
# 1  Yellowknife      CA  62.4560 -114.3525     50.56        57          40
# 2     Skjervoy      NO  70.0311   20.9714     48.20        88         100
# 3         Auch      FR  43.6500    0.5833     65.34        81          39
# 4    Killybegs      IE  54.6333   -8.4500     56.91        85         100
#
#    Wind Speed
# 0       30.24
# 1       10.36
# 2       21.68
# 3        3.18
# 4       25.41

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE

city_data_df.to_csv(output_data_file)
